# %% [markdown]
# <a name='1-1'></a>
# ## 1.1 Import Packages

# %%
import os
import numpy as np
import glob as gb
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import cv2
import random


import tensorflow as tf
import tensorflow.keras.layers as tfl

from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom, RandomContrast
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing import image
from keras.regularizers import l2
from keras import Sequential

sns.set()
# %matplotlib inline

# %%
train_directory = './dataset/train'
test_directory = './dataset/test'
val_directory = './dataset/val'

# %%
HYPERPARAM = {
    "IMG_SIZE": (224,224),
    "BATCH_SIZE": 16,
    "EPOCHS": 10,
    "LEARNING_RATE": 0.001
}

# %%
train_datagen = image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True, 
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=[0.8, 1.2], 
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input  # Normalize using ResNet V2 preprocessing
)

val_datagen = image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input  # Normalize using ResNet V2 preprocessing
)

test_datagen = image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input  # Normalize using ResNet V2 preprocessing
)

# %% [markdown]
# <a name='1-3'></a>
#
# ## 1.2 Create the Dataset and Split it into Training and Validation Sets

# %%
train_dataset = train_datagen.flow_from_directory(train_directory,
                                             batch_size=HYPERPARAM['BATCH_SIZE'],
                                             target_size=HYPERPARAM['IMG_SIZE'],
                                             class_mode = 'binary')
val_dataset = val_datagen.flow_from_directory(val_directory,
                                             shuffle=True,
                                             batch_size=HYPERPARAM['BATCH_SIZE'],
                                             target_size=HYPERPARAM['IMG_SIZE'],
                                             class_mode = 'binary')
test_dataset = test_datagen.flow_from_directory(test_directory,
                                             shuffle=True,
                                             batch_size=HYPERPARAM['BATCH_SIZE'],
                                             target_size=HYPERPARAM['IMG_SIZE'],
                                             class_mode = 'binary')
# Out:
# Found 7570 images belonging to 2 classes.
# Found 946 images belonging to 2 classes.
# Found 947 images belonging to 2 classes.

# %% [markdown]
# <a name='2-1'></a>
# ## 2.1 Check Labels of Images

# %%
images, labels = next(train_dataset)

# Plot the first four images and their labels
fig, axs = plt.subplots(1, 4, figsize=(10, 10))
for i in range(4):
    axs[i].imshow(images[i][:, :, 0], cmap='gray')  # Display the first channel of the image (grayscale)
    axs[i].axis('off')
    axs[i].set_title('{}'.format(labels[i]))

plt.show()

# %%
images, labels = next(train_dataset)

# Plot the first four images and their labels
fig, axs = plt.subplots(1, 4, figsize=(10, 10))
for i in range(4):
    axs[i].imshow(images[i][:, :, 0], cmap='gray')  # Display the first channel of the image (grayscale)
    axs[i].axis('off')
    axs[i].set_title('{}'.format(labels[i]))

plt.show()

# %%
#Take preprocessing function from module inception_v3 
preprocess_input = tf.keras.applications.efficientnet.preprocess_input

# %% [markdown]
# <a name='3-1'></a>
# ## 3.1 Building Final Edition Model

# %%
input_shape = HYPERPARAM['IMG_SIZE'] + (3,)

# Define a pre-trained model
base_model = tf.keras.applications.EfficientNetB0(include_top=False, input_shape=input_shape)

# Freeze all the layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Create a new model on top of the pre-trained base model
inputs = tf.keras.Input(shape=input_shape)
x = base_model(inputs)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
model = tf.keras.Model(inputs, outputs)

# Compile the model
optimizer = tf.keras.optimizers.Adam(lr=HYPERPARAM['LEARNING_RATE'])
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 1s 0us/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 256)               327936
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 4412068 (16.83 MB)
# Trainable params: 361729 (1.38 MB)
# Non-trainable params: 4050339 (15.45 MB)
# _________________________________________________________________

# %%
loss_function=tf.losses.BinaryCrossentropy(from_logits=False)
optimizer = tf.optimizers.Adam(learning_rate=HYPERPARAM['LEARNING_RATE'])

metrics=['accuracy']
model.compile(loss=loss_function,
              optimizer = optimizer,
              metrics=metrics)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# <a name='3-2'></a>
# ## 3.2 Train Model on our Data

# %%
lrp=ReduceLROnPlateau(monitor="val_loss", factor=0.01, patience=2)
checkpoint_filepath = 'best_model.h5'
# Define early stopping and checkpoint callbacks
# early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1)
checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_accuracy', mode='max', save_best_only=True, verbose = 1)

try:
    model = tf.keras.models.load_model(checkpoint_filepath)
    print("loaded model from filepath")
except:
    print("Checkpoint not found")
    
train_samples = train_datagen.flow_from_directory(train_directory).samples
val_samples = val_datagen.flow_from_directory(val_directory).samples
batch_size = HYPERPARAM["BATCH_SIZE"]

steps_per_epoch = train_samples // batch_size
validation_steps = val_samples // batch_size
# Train the model with callbacks
history = model.fit(train_dataset,
                    epochs=HYPERPARAM['EPOCHS'],
                    steps_per_epoch= steps_per_epoch,
                    validation_steps = validation_steps,
                    validation_data=val_dataset,
                    callbacks=[checkpoint,lrp])
# Out:
# Checkpoint not found
# Found 7570 images belonging to 2 classes.
# Found 946 images belonging to 2 classes.
# Epoch 1/10
# 473/473 [==============================] - ETA: 0s - loss: 0.5366 - accuracy: 0.7294
# Epoch 1: val_accuracy improved from -inf to 0.81144, saving model to best_model.h5
# 473/473 [==============================] - 182s 386ms/step - loss: 0.5366 - accuracy: 0.7294 - val_loss: 0.4560 - val_accuracy: 0.8114 - lr: 0.0010
# Epoch 2/10
# /Users/cam/opt/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 473/473 [==============================] - ETA: 0s - loss: 0.4863 - accuracy: 0.7661
# Epoch 2: val_accuracy improved from 0.81144 to 0.82415, saving model to best_model.h5
# 473/473 [==============================] - 181s 383ms/step - loss: 0.4863 - accuracy: 0.7661 - val_loss: 0.3969 - val_accuracy: 0.8242 - lr: 0.0010
# Epoch 3/10
# 473/473 [==============================] - ETA: 0s - loss: 0.4607 - accuracy: 0.7847
# Epoch 3: val_accuracy improved from 0.82415 to 0.85064, saving model to best_model.h5
# 473/473 [==============================] - 173s 366ms/step - loss: 0.4607 - accuracy: 0.7847 - val_loss: 0.3627 - val_accuracy: 0.8506 - lr: 0.0010
# Epoch 4/10
# 473/473 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.7879
# Epoch 4: val_accuracy improved from 0.85064 to 0.85699, saving model to best_model.h5
# 473/473 [==============================] - 184s 388ms/step - loss: 0.4470 - accuracy: 0.7879 - val_loss: 0.3488 - val_accuracy: 0.8570 - lr: 0.0010
# Epoch 5/10
# 473/473 [==============================] - ETA: 0s - loss: 0.4380 - accuracy: 0.7911
# Epoch 5: val_accuracy improved from 0.85699 to 0.86123, saving model to best_model.h5
# 473/473 [==============================] - 187s 394ms/step - loss: 0.4380 - accuracy: 0.7911 - val_loss: 0.3372 - val_accuracy: 0.8612 - lr: 0.0010
# Epoch 6/10
# 473/473 [==============================] - ETA: 0s - loss: 0.4230 - accuracy: 0.8065
# Epoch 6: val_accuracy improved from 0.86123 to 0.86547, saving model to best_model.h5
# 473/473 [==============================] - 178s 375ms/step - loss: 0.4230 - accuracy: 0.8065 - val_loss: 0.3150 - val_accuracy: 0.8655 - lr: 0.0010
# Epoch 7/10
# 473/473 [==============================] - ETA: 0s - loss: 0.4158 - accuracy: 0.8118
# Epoch 7: val_accuracy did not improve from 0.86547
# 473/473 [==============================] - 198s 418ms/step - loss: 0.4158 - accuracy: 0.8118 - val_loss: 0.3378 - val_accuracy: 0.8559 - lr: 0.0010
# Epoch 8/10
# 473/473 [==============================] - ETA: 0s - loss: 0.4078 - accuracy: 0.8176
# Epoch 8: val_accuracy improved from 0.86547 to 0.88347, saving model to best_model.h5
# 473/473 [==============================] - 197s 416ms/step - loss: 0.4078 - accuracy: 0.8176 - val_loss: 0.2886 - val_accuracy: 0.8835 - lr: 0.0010
# Epoch 9/10
# 473/473 [==============================] - ETA: 0s - loss: 0.3960 - accuracy: 0.8231
# Epoch 9: val_accuracy improved from 0.88347 to 0.88665, saving model to best_model.h5
# 473/473 [==============================] - 207s 437ms/step - loss: 0.3960 - accuracy: 0.8231 - val_loss: 0.3096 - val_accuracy: 0.8867 - lr: 0.0010
# Epoch 10/10
# 473/473 [==============================] - ETA: 0s - loss: 0.3934 - accuracy: 0.8241
# Epoch 10: val_accuracy improved from 0.88665 to 0.90466, saving model to best_model.h5
# 473/473 [==============================] - 197s 417ms/step - loss: 0.3934 - accuracy: 0.8241 - val_loss: 0.2517 - val_accuracy: 0.9047 - lr: 0.0010

# %%
sns.set()

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))

# Plot Training Accuracy
ax1.plot([0.] + history.history['accuracy'], color='b', label='Training Accuracy')
ax1.plot([0.] + history.history['val_accuracy'], color='r', label='Validation Accuracy')
ax1.set_ylim([0, 1])
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('Accuracy')
ax1.set_title('Training and Validation Accuracy')

# Plot Training Loss
ax2.plot(history.history['loss'], color='b', label='Training Loss')
ax2.plot(history.history['val_loss'], color='r', label='Validation Loss')
ax2.set_ylim([0, 1])
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('Cross Entropy')
ax2.set_xlabel('Epoch')
ax2.set_title('Training and Validation Loss')

plt.show()

# %%
total_epochs =  HYPERPARAM['EPOCHS'] + 5
#Train model on 5 more epochs
history_More = model.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         steps_per_epoch= 50,
                         validation_data=val_dataset)
# Out:
# Epoch 10/15
# 50/50 [==============================] - 39s 781ms/step - loss: 0.3685 - accuracy: 0.8338 - val_loss: 0.2915 - val_accuracy: 0.8626
# Epoch 11/15
# 50/50 [==============================] - 39s 778ms/step - loss: 0.3861 - accuracy: 0.8263 - val_loss: 0.3077 - val_accuracy: 0.8710
# Epoch 12/15
# 50/50 [==============================] - 39s 779ms/step - loss: 0.3695 - accuracy: 0.8397 - val_loss: 0.2801 - val_accuracy: 0.8922
# Epoch 13/15
# 50/50 [==============================] - 39s 780ms/step - loss: 0.3841 - accuracy: 0.8200 - val_loss: 0.2664 - val_accuracy: 0.9038
# Epoch 14/15
# 50/50 [==============================] - 39s 781ms/step - loss: 0.3627 - accuracy: 0.8438 - val_loss: 0.2627 - val_accuracy: 0.8890
# Epoch 15/15
# 50/50 [==============================] - 40s 800ms/step - loss: 0.3909 - accuracy: 0.8175 - val_loss: 0.2650 - val_accuracy: 0.8996

# %% [markdown]
# <a name='4'></a>
# # 4 - Evaluation Model

# %%
#add more epochs to plot
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

acc += history_More.history['accuracy']
val_acc += history_More.history['val_accuracy']

loss += history_More.history['loss']
val_loss += history_More.history['val_loss']

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(acc, color='b',  label='Training Accuracy')
ax1.plot(val_acc, color='r',  label='Validation Accuracy')
ax1.set_ylim([0, 1])
ax1.plot([HYPERPARAM['EPOCHS']-1,HYPERPARAM['EPOCHS']-1],
          plt.ylim(), 'g--', label='After 5 More Epochs')
ax1.legend(loc='best', shadow=True)
ax1.set_title('Training and Validation Accuracy')

ax2.plot(loss, color='b',  label='Training Loss')
ax2.plot(val_loss, color='r', label='Validation Loss')
ax2.set_ylim([0, 1.0])
ax2.plot([HYPERPARAM['EPOCHS']-1,HYPERPARAM['EPOCHS']-1],
         plt.ylim(), 'g--', label='After 5 More Epochs')
ax2.legend(loc='best', shadow=True)
ax2.set_title('Training and Validation Loss')
ax2.set_xlabel('epoch')
plt.tight_layout()
plt.show()

# %%
model.save('v1_bone_fracture_model.h5')

# %%
model.save_weights('v1_bone_fracture_weights.h5')

# %%
model.load_weights('v1_bone_fracture_model.h5')
test_loss, test_accuracy = model.evaluate(test_dataset)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# 60/60 [==============================] - 20s 325ms/step - loss: 0.2738 - accuracy: 0.8912
# Test Loss: 0.2737516462802887
# Test Accuracy: 0.8912354707717896
